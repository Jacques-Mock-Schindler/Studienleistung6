# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from matplotlib.ticker import FuncFormatter

# %%
x = [i for i in range(1, 10001)]
y_lin = [i for i in x]

# %%
y_log = [math.log2(i) for i in x]

# %%
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %%
plt.plot(x, y_lin, color="red", label="$f(x)=x$")
plt.plot(x, y_log, color="green", label="$g(x)=log_2 x$")
plt.suptitle("Lineares und logarithmisches Wachstum")
plt.title("(Gegenüberstellung)")
plt.xlabel("Anzahl Elemente in der Suchsequenz")
plt.ylabel("Maximal erforderliche Vergleiche")
plt.legend(frameon=False, loc="upper left")
plt.savefig("lin_log.svg")
plt.show()

# %%
print(math.log2(10_000))
# Out:
# 13.287712379549449

# %%
2**13
# Out:
# 8192

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

axes[0].plot(x, y_log, color="green", label="$g(x)=log_2(x)$")
axes[0].set_ylabel("Maximal erforderliche Vergleiche")
axes[0].set_xlabel("Anzahl Elemente in der Suchsequenz")
axes[0].set_title("Logarithmisches Wachstum")
axes[0].legend(frameon=False, loc='upper left')

axes[1].plot(x, y_lin, color="red", label="$f(x)=x$")
axes[1].plot(x, y_log, color="green", label="$g(x)=log_2(x)$")  
axes[1].set_ylabel("Maximal erforderliche Vergleiche")
axes[1].set_xlabel("Anzahl Elemente in der Suchsequenz")
axes[1].set_title("Lineares und logarithmisches Wachstum im Vergleich")
axes[1].legend(frameon=False, loc='upper left')


fig.tight_layout()


plt.savefig("lin_log.svg")
plt.show()

# %%
for i in range(1,25):
    print(y_log[i])
# Out:
# 1.0
# 1.584962500721156
# 2.0
# 2.321928094887362
# 2.584962500721156
# 2.807354922057604
# 3.0
# 3.169925001442312
# 3.321928094887362
# 3.4594316186372973
# 3.584962500721156
# 3.700439718141092
# 3.807354922057604
# 3.9068905956085187
# 4.0
# 4.087462841250339
# 4.169925001442312
# 4.247927513443585
# 4.321928094887363
# 4.392317422778761
# 4.459431618637297
# 4.523561956057013
# 4.584962500721156
# 4.643856189774724

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FuncFormatter

# Beispieldaten erstellen
x = np.arange(0, 100)
y = x ** 2

# Plot erstellen
plt.figure(figsize=(10, 6))
plt.plot(x, y)

# Tausendertrennzeichen für die Y-Achse einstellen
formatter = FuncFormatter(lambda x, _: f'{x:,.0f}')
plt.gca().yaxis.set_major_formatter(formatter)

plt.title("Plot mit Tausendertrennzeichen")
plt.xlabel("X-Achse")
plt.ylabel("Y-Achse")

plt.show()
